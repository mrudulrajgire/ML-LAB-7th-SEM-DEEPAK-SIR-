# %% [markdown]
# <a href="https://colab.research.google.com/github/mrudulrajgire/ML-LAB-7th-SEM-DEEPAK-SIR-/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris

# %%
pip install numpy pandas matplotlib seaborn scikit-learn

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
print(df.head())
print(df.info())
print(df.describe())
print(df['species'].value_counts())
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                5.1               3.5  ...               0.2   setosa
# 1                4.9               3.0  ...               0.2   setosa
# 2                4.7               3.2  ...               0.2   setosa
# 3                4.6               3.1  ...               0.2   setosa
# 4                5.0               3.6  ...               0.2   setosa
#
# [5 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB
# None
# ...

# %%
df.hist(figsize=(10, 6), bins=20)
plt.suptitle("Histograms of features columns")
plt.show()

# %%
sns.pairplot(df, hue="species")
plt.suptitle("Pair Plot of Feature Columns", y=1.02)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, orient="h")

plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.iloc[:, :-1].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
